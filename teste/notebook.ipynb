# %% [markdown]
# # Teste dos Endpoints
#
# Notebook para testar os endpoints de upload e métricas.

# %%
import requests
import json

BASE_URL = "http://localhost:8000"

# %% [markdown]
# ## 1. Upload

# %%
# Ajuste o caminho para o seu arquivo CSV/XLSX
FILE_PATH = "teste/dados.xlsx"

with open(FILE_PATH, "rb") as f:
    resp = requests.post(
        f"{BASE_URL}/files/upload",
        files={"file": (FILE_PATH.split('/')[-1], f)},
    )

print(resp.status_code)
upload_result = resp.json()
print(json.dumps(upload_result, indent=2))

# Salvar o ingestion_id para usar nos próximos testes
ingestion_id = upload_result["ingestion_id"]
print(f"\ningestion_id: {ingestion_id}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Ajuste o caminho para o seu arquivo CSV/XLSX
#       2 FILE_PATH = "data/teste/dados.xlsx"
#       3
# ----> 4 with open(FILE_PATH, "rb") as f:
#       5     resp = requests.post(
#       6         f"{BASE_URL}/files/upload",
#       7         files={"file": (FILE_PATH.split('/')[-1], f)},
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/teste/dados.xlsx'

# %% [markdown]
# ## 2. Métricas Consolidadas

# %%
resp = requests.post(
    f"{BASE_URL}/metrics/",
    json={"ingestion_id": ingestion_id},
)

print(resp.status_code)
print(json.dumps(resp.json(), indent=2))
# Out:
# 200
# {
#   "ingestion_id": "182235f6-3aff-4662-abc2-7a3ac77e3df3",
#   "total_registros": 4000,
#   "metricas": {
#     "receita": {
#       "receita_total": 10103809.95,
#       "receita_real": 7068900.65,
#       "receita_inadimplente": 1000195.79
#     },
#     "ticket": {
#       "ticket_medio": 2525.9524874999997
#     },
#     "taxa": {
#       "taxa_inadimplencia": 9.62
#     }
#   }
# }

# %% [markdown]
# ## 3. Métricas Disponíveis

# %%
resp = requests.get(f"{BASE_URL}/metrics/available")

print(resp.status_code)
print(json.dumps(resp.json(), indent=2))
# Out:
# 200
# {
#   "metrics": [
#     {
#       "name": "receita_total",
#       "group": "receita"
#     },
#     {
#       "name": "receita_real",
#       "group": "receita"
#     },
#     {
#       "name": "receita_inadimplente",
#       "group": "receita"
#     },
#     {
#       "name": "ticket_medio",
#       "group": "ticket"
#     },
#     {
#       "name": "taxa_inadimplencia",
#       "group": "taxa"
#     }
#   ],
#   "groups": {
#     "receita": [
#       "receita_total",
#       "receita_real",
#       "receita_inadimplente"
#     ],
#     "ticket": [
#       "ticket_medio"
#     ],
#     "taxa": [
#       "taxa_inadimplencia"
#     ]
#   }
# }

# %% [markdown]
# ## 4. Evolução Temporal

# %%
# Todas as métricas de receita juntas
resp = requests.post(
    f"{BASE_URL}/metrics/temporal",
    json={
        "ingestion_id": ingestion_id,
        "metric_names": ["receita_total", "receita_real", "receita_inadimplente"],
        "freq": "M",
        "mode": "pontual",
    },
)

print(resp.status_code)
print(json.dumps(resp.json(), indent=2, default=str))
# Out:
# 200
# {
#   "ingestion_id": "182235f6-3aff-4662-abc2-7a3ac77e3df3",
#   "total_registros": 4000,
#   "freq": "M",
#   "mode": "pontual",
#   "evolucao": {
#     "receita": [
#       {
#         "datas": [
#           "2024-01-01T00:00:00",
#           "2024-02-01T00:00:00",
#           "2024-03-01T00:00:00",
#           "2024-04-01T00:00:00",
#           "2024-05-01T00:00:00",
#           "2024-06-01T00:00:00",
#           "2024-07-01T00:00:00",
#           "2024-08-01T00:00:00",
#           "2024-09-01T00:00:00",
#           "2024-10-01T00:00:00",
#           "2024-11-01T00:00:00",
#           "2024-12-01T00:00:00",
#           "2025-01-01T00:00:00",
#           "2025-02-01T00:00:00",
#           "2025-03-01T00:00:00",
#           "2025-04-01T00:00:00",
#           "2025-05-01T00:00:00",
#           "2025-06-01T00:00:00",
#           "2025-07-01T00:00:00",
#           "2025-08-01T00:00:00",
#           "2025-09-01T00:00:00",
#           "2025-10-01T00:00:00",
#           "2025-11-01T00:00:00",
#           "2025-12-01T00:00:00"
#         ],
#         "valores": [
#           414058.05,
#           408993.66,
#           413184.8,
#           509730.8,
#           478814.99,
#           423180.91,
#           371188.19999999995,
#           492255.12,
#           451749.03,
#           467938.99,
#           496292.4,
#           443613.02,
#           446174.67,
#           342224.86,
#           479815.2199999999,
#           476811.29000000004,
#           371966.58999999997,
#           397864.64999999997,
#           432746.03,
#           452054.3,
#           386138.13,
#           453483.88,
#           484703.9199999999,
#           8826.439999999999
#         ],
#         "freq": "M",
#         "mode": "pontual",
#         "metric_name": "receita_total"
#       },
#       {
#         "datas": [
#           "2024-01-01T00:00:00",
#           "2024-02-01T00:00:00",
#           "2024-03-01T00:00:00",
#           "2024-04-01T00:00:00",
#           "2024-05-01T00:00:00",
#           "2024-06-01T00:00:00",
#           "2024-07-01T00:00:00",
#           "2024-08-01T00:00:00",
#           "2024-09-01T00:00:00",
#           "2024-10-01T00:00:00",
#           "2024-11-01T00:00:00",
#           "2024-12-01T00:00:00",
#           "2025-01-01T00:00:00",
#           "2025-02-01T00:00:00",
#           "2025-03-01T00:00:00",
#           "2025-04-01T00:00:00",
#           "2025-05-01T00:00:00",
#           "2025-06-01T00:00:00",
#           "2025-07-01T00:00:00",
#           "2025-08-01T00:00:00",
#           "2025-09-01T00:00:00",
#           "2025-10-01T00:00:00",
#           "2025-11-01T00:00:00",
#           "2025-12-01T00:00:00"
#         ],
#         "valores": [
#           295904.67,
#           271412.41000000003,
#           293252.1,
#           366465.76,
#           331874.88,
#           311116.55,
#           238639.51,
#           324060.67000000004,
#           301970.67000000004,
#           367456.74,
#           323102.12000000005,
#           281130.01999999996,
#           311200.39,
#           255735.25,
#           353790.06000000006,
#           366793.63,
#           264436.91000000003,
#           253969.99999999997,
#           328088.93,
#           281694.9800000001,
#           239323.24,
#           322653.36999999994,
#           376001.35,
#           8826.439999999999
#         ],
#         "freq": "M",
#         "mode": "pontual",
#         "metric_name": "receita_real"
#       },
#       {
#         "datas": [
#           "2024-01-01T00:00:00",
#           "2024-02-01T00:00:00",
#           "2024-03-01T00:00:00",
#           "2024-04-01T00:00:00",
#           "2024-05-01T00:00:00",
#           "2024-06-01T00:00:00",
#           "2024-07-01T00:00:00",
#           "2024-08-01T00:00:00",
#           "2024-09-01T00:00:00",
#           "2024-10-01T00:00:00",
#           "2024-11-01T00:00:00",
#           "2024-12-01T00:00:00",
#           "2025-01-01T00:00:00",
#           "2025-02-01T00:00:00",
#           "2025-03-01T00:00:00",
#           "2025-04-01T00:00:00",
#           "2025-05-01T00:00:00",
#           "2025-06-01T00:00:00",
#           "2025-07-01T00:00:00",
#           "2025-08-01T00:00:00",
#           "2025-09-01T00:00:00",
#           "2025-10-01T00:00:00",
#           "2025-11-01T00:00:00",
#           "2025-12-01T00:00:00"
#         ],
#         "valores": [
#           41946.899999999994,
#           34834.47,
#           33924.06,
#           49474.87,
#           47769.43,
#           35902.149999999994,
#           54366.37,
#           76334.31000000001,
#           37634.840000000004,
#           30773.87,
#           48365.06,
#           54419.51999999999,
#           44148.40000000001,
#           19076.34,
#           46429.57,
#           14790.94,
#           34864.01,
#           49470.159999999996,
#           29933.829999999998,
#           75519.65,
#           35751.45,
#           54401.97,
#           50063.62,
#           0.0
#         ],
#         "freq": "M",
#         "mode": "pontual",
#         "metric_name": "receita_inadimplente"
#       }
#     ]
#   }
# }

# %%
# Ticket médio
resp = requests.post(
    f"{BASE_URL}/metrics/temporal",
    json={
        "ingestion_id": ingestion_id,
        "metric_names": ["ticket_medio"],
        "freq": "M",
        "mode": "pontual",
    },
)

print(resp.status_code)
print(json.dumps(resp.json(), indent=2, default=str))
# Out:
# 200
# {
#   "ingestion_id": "182235f6-3aff-4662-abc2-7a3ac77e3df3",
#   "total_registros": 4000,
#   "freq": "M",
#   "mode": "pontual",
#   "evolucao": {
#     "ticket": [
#       {
#         "datas": [
#           "2024-01-01T00:00:00",
#           "2024-02-01T00:00:00",
#           "2024-03-01T00:00:00",
#           "2024-04-01T00:00:00",
#           "2024-05-01T00:00:00",
#           "2024-06-01T00:00:00",
#           "2024-07-01T00:00:00",
#           "2024-08-01T00:00:00",
#           "2024-09-01T00:00:00",
#           "2024-10-01T00:00:00",
#           "2024-11-01T00:00:00",
#           "2024-12-01T00:00:00",
#           "2025-01-01T00:00:00",
#           "2025-02-01T00:00:00",
#           "2025-03-01T00:00:00",
#           "2025-04-01T00:00:00",
#           "2025-05-01T00:00:00",
#           "2025-06-01T00:00:00",
#           "2025-07-01T00:00:00",
#           "2025-08-01T00:00:00",
#           "2025-09-01T00:00:00",
#           "2025-10-01T00:00:00",
#           "2025-11-01T00:00:00",
#           "2025-12-01T00:00:00"
#         ],
#         "valores": [
#           2366.046,
#           2478.7494545454542,
#           2615.093670886076,
#           2574.3979797979796,
#           2560.5079679144383,
#           2596.201901840491,
#           2394.762580645161,
#           2436.9065346534653,
#           2537.9158988764048,
#           2529.399945945946,
#           2726.8813186813186,
#           2385.01623655914,
#           2492.5959217877094,
#           2444.4632857142856,
#           2525.3432631578944,
#           2522.8110582010586,
#           2384.4012179487177,
#           2502.293396226415,
#           2560.6273964497045,
#           2643.5923976608187,
#           2523.7786274509804,
#           2731.8306024096387,
#           2537.716858638743,
#           2942.146666666666
#         ],
#         "freq": "M",
#         "mode": "pontual",
#         "metric_name": "ticket_medio"
#       }
#     ]
#   }
# }

# %%
# Taxa de inadimplência
resp = requests.post(
    f"{BASE_URL}/metrics/temporal",
    json={
        "ingestion_id": ingestion_id,
        "metric_names": ["taxa_inadimplencia"],
        "freq": "M",
        "mode": "pontual",
    },
)

print(resp.status_code)
print(json.dumps(resp.json(), indent=2, default=str))
# Out:
# 200
# {
#   "ingestion_id": "182235f6-3aff-4662-abc2-7a3ac77e3df3",
#   "total_registros": 4000,
#   "freq": "M",
#   "mode": "pontual",
#   "evolucao": {
#     "taxa": [
#       {
#         "datas": [
#           "2024-01-01T00:00:00",
#           "2024-02-01T00:00:00",
#           "2024-03-01T00:00:00",
#           "2024-04-01T00:00:00",
#           "2024-05-01T00:00:00",
#           "2024-06-01T00:00:00",
#           "2024-07-01T00:00:00",
#           "2024-08-01T00:00:00",
#           "2024-09-01T00:00:00",
#           "2024-10-01T00:00:00",
#           "2024-11-01T00:00:00",
#           "2024-12-01T00:00:00",
#           "2025-01-01T00:00:00",
#           "2025-02-01T00:00:00",
#           "2025-03-01T00:00:00",
#           "2025-04-01T00:00:00",
#           "2025-05-01T00:00:00",
#           "2025-06-01T00:00:00",
#           "2025-07-01T00:00:00",
#           "2025-08-01T00:00:00",
#           "2025-09-01T00:00:00",
#           "2025-10-01T00:00:00",
#           "2025-11-01T00:00:00",
#           "2025-12-01T00:00:00"
#         ],
#         "valores": [
#           9.14,
#           6.67,
#           8.86,
#           10.1,
#           10.16,
#           9.2,
#           12.9,
#           15.35,
#           9.55,
#           7.03,
#           8.24,
#           11.29,
#           10.06,
#           6.43,
#           7.89,
#           4.23,
#           9.62,
#           11.95,
#           5.33,
#           15.79,
#           9.8,
#           11.45,
#           9.95,
#           0.0
#         ],
#         "freq": "M",
#         "mode": "pontual",
#         "metric_name": "taxa_inadimplencia"
#       }
#     ]
#   }
# }
